# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### importing data into python enviroment.

# %%
df = pd.read_csv(r"Comcast_telecom_complaints_data.csv")

# %%
df
# Out:
#      Ticket #                                 Customer Complaint      Date  \
# 0      250635                      Comcast Cable Internet Speeds  22-04-15
# 1      223441       Payment disappear - service got disconnected  04-08-15
# 2      242732                                  Speed and Service  18-04-15
# 3      277946  Comcast Imposed a New Usage Cap of 300GB that ...  05-07-15
# 4      307175         Comcast not working and no service to boot  26-05-15
# ...       ...                                                ...       ...
# 2219   213550                               Service Availability  04-02-15
# 2220   318775         Comcast Monthly Billing for Returned Modem  06-02-15
# 2221   331188                            complaint about comcast  06-09-15
# 2222   360489             Extremely unsatisfied Comcast customer  23-06-15
# 2223   363614               Comcast, Ypsilanti MI Internet Speed  24-06-15
#
# ...

# %% [markdown]
# ## Extracting the customer complaints and categorizing them:

# %%
len(list(df['Customer Complaint'].unique()))
# Out:
# 1841

# %%
complaint_list= list(df['Customer Complaint'].unique())

# %%
dataf = df.copy()

# %%
from sklearn.feature_extraction.text import CountVectorizer
corpus= dataf['Customer Complaint']
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(corpus)
y1= vectorizer.get_feature_names()

# %%
cust_complaints1 = dataf.loc[df['Customer Complaint'].str.contains('comcast', case=False)]
cust_complaints1
for i in cust_complaints1.index:
        (dataf['Customer Complaint'][i])='Comcast Support Issue'
    
dataf
# Out:
# <ipython-input-13-246c639629b0>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   (dataf['Customer Complaint'][i])='Comcast Support Issue'
#      Ticket #                            Customer Complaint      Date  \
# 0      250635                         Comcast Support Issue  22-04-15
# 1      223441  Payment disappear - service got disconnected  04-08-15
# 2      242732                             Speed and Service  18-04-15
# 3      277946                         Comcast Support Issue  05-07-15
# 4      307175                         Comcast Support Issue  26-05-15
# ...       ...                                           ...       ...
# 2219   213550                          Service Availability  04-02-15
# 2220   318775                         Comcast Support Issue  06-02-15
# ...

# %%
cust_complaints2 = dataf.loc[df['Customer Complaint'].str.contains("bill" , case=False)]
cust_complaints2
for i in cust_complaints2.index:
        (dataf['Customer Complaint'][i])='bill issue'
    
dataf
# Out:
# <ipython-input-14-fa0a5cad0a8e>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   (dataf['Customer Complaint'][i])='bill issue'
#      Ticket #                            Customer Complaint      Date  \
# 0      250635                         Comcast Support Issue  22-04-15
# 1      223441  Payment disappear - service got disconnected  04-08-15
# 2      242732                             Speed and Service  18-04-15
# 3      277946                         Comcast Support Issue  05-07-15
# 4      307175                         Comcast Support Issue  26-05-15
# ...       ...                                           ...       ...
# 2219   213550                          Service Availability  04-02-15
# 2220   318775                                    bill issue  06-02-15
# ...

# %%
cust_complaints3 = dataf.loc[df['Customer Complaint'].str.contains("speed", case=False)]
cust_complaints3
for i in cust_complaints3.index:
    (dataf['Customer Complaint'][i])='Network Issue'
    
dataf
# Out:
# <ipython-input-15-1fd383d02b52>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   (dataf['Customer Complaint'][i])='Network Issue'
#      Ticket #                            Customer Complaint      Date  \
# 0      250635                                 Network Issue  22-04-15
# 1      223441  Payment disappear - service got disconnected  04-08-15
# 2      242732                                 Network Issue  18-04-15
# 3      277946                         Comcast Support Issue  05-07-15
# 4      307175                         Comcast Support Issue  26-05-15
# ...       ...                                           ...       ...
# 2219   213550                          Service Availability  04-02-15
# 2220   318775                                    bill issue  06-02-15
# ...

# %%
cust_complaints4 = dataf.loc[df['Customer Complaint'].str.contains("internet", case=False)]
cust_complaints4
for i in cust_complaints4.index:
    (dataf['Customer Complaint'][i])='Internet Issue'
    
dataf
# Out:
# <ipython-input-16-4b9c922472ce>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   (dataf['Customer Complaint'][i])='Internet Issue'
#      Ticket #                            Customer Complaint      Date  \
# 0      250635                                Internet Issue  22-04-15
# 1      223441  Payment disappear - service got disconnected  04-08-15
# 2      242732                                 Network Issue  18-04-15
# 3      277946                         Comcast Support Issue  05-07-15
# 4      307175                         Comcast Support Issue  26-05-15
# ...       ...                                           ...       ...
# 2219   213550                          Service Availability  04-02-15
# 2220   318775                                    bill issue  06-02-15
# ...

# %%
cust_complaints5 = dataf.loc[df['Customer Complaint'].str.contains("payment", case=False)]
cust_complaints5
for i in cust_complaints5.index:
        (dataf['Customer Complaint'][i])='Payment Issue'
    
dataf
# Out:
# <ipython-input-17-a8ecc1b9a173>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   (dataf['Customer Complaint'][i])='Payment Issue'
#      Ticket #     Customer Complaint      Date Date_month_year         Time  \
# 0      250635         Internet Issue  22-04-15       22-Apr-15   3:53:50 PM
# 1      223441          Payment Issue  04-08-15       04-Aug-15  10:22:56 AM
# 2      242732          Network Issue  18-04-15       18-Apr-15   9:55:47 AM
# 3      277946  Comcast Support Issue  05-07-15       05-Jul-15  11:59:35 AM
# 4      307175  Comcast Support Issue  26-05-15       26-May-15   1:25:26 PM
# ...       ...                    ...       ...             ...          ...
# 2219   213550   Service Availability  04-02-15       04-Feb-15   9:13:18 AM
# ...

# %%
cust_complaints6 = dataf.loc[df['Customer Complaint'].str.contains("cap", case=False)]
cust_complaints6
for i in cust_complaints6.index:
        (dataf['Customer Complaint'][i])='Data Cap Issue'
    
dataf
# Out:
# <ipython-input-18-343d1b31534c>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   (dataf['Customer Complaint'][i])='Data Cap Issue'
#      Ticket #     Customer Complaint      Date Date_month_year         Time  \
# 0      250635         Internet Issue  22-04-15       22-Apr-15   3:53:50 PM
# 1      223441          Payment Issue  04-08-15       04-Aug-15  10:22:56 AM
# 2      242732          Network Issue  18-04-15       18-Apr-15   9:55:47 AM
# 3      277946         Data Cap Issue  05-07-15       05-Jul-15  11:59:35 AM
# 4      307175  Comcast Support Issue  26-05-15       26-May-15   1:25:26 PM
# ...       ...                    ...       ...             ...          ...
# 2219   213550   Service Availability  04-02-15       04-Feb-15   9:13:18 AM
# ...

# %%
cust_complaints7 = dataf.loc[df['Customer Complaint'].str.contains("billing" , case=False)]
cust_complaints7                                                                   
for i in cust_complaints7.index:
    (dataf['Customer Complaint'][i])='Billing Issue'
    
dataf
# Out:
# <ipython-input-19-91a28fe0e2fa>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   (dataf['Customer Complaint'][i])='Billing Issue'
#      Ticket #     Customer Complaint      Date Date_month_year         Time  \
# 0      250635         Internet Issue  22-04-15       22-Apr-15   3:53:50 PM
# 1      223441          Payment Issue  04-08-15       04-Aug-15  10:22:56 AM
# 2      242732          Network Issue  18-04-15       18-Apr-15   9:55:47 AM
# 3      277946         Data Cap Issue  05-07-15       05-Jul-15  11:59:35 AM
# 4      307175  Comcast Support Issue  26-05-15       26-May-15   1:25:26 PM
# ...       ...                    ...       ...             ...          ...
# 2219   213550   Service Availability  04-02-15       04-Feb-15   9:13:18 AM
# ...

# %%
cust_complaints8 = dataf.loc[df['Customer Complaint'].str.contains("service", case=False)]
cust_complaints8
for i in cust_complaints8.index:
        (dataf['Customer Complaint'][i])='Service Issue'
    
dataf
# Out:
# <ipython-input-20-9dc9ad37286b>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   (dataf['Customer Complaint'][i])='Service Issue'
#      Ticket #     Customer Complaint      Date Date_month_year         Time  \
# 0      250635         Internet Issue  22-04-15       22-Apr-15   3:53:50 PM
# 1      223441          Service Issue  04-08-15       04-Aug-15  10:22:56 AM
# 2      242732          Service Issue  18-04-15       18-Apr-15   9:55:47 AM
# 3      277946         Data Cap Issue  05-07-15       05-Jul-15  11:59:35 AM
# 4      307175          Service Issue  26-05-15       26-May-15   1:25:26 PM
# ...       ...                    ...       ...             ...          ...
# 2219   213550          Service Issue  04-02-15       04-Feb-15   9:13:18 AM
# ...

# %%
for i in dataf.index:
    if (dataf['Customer Complaint'][i]== 'Service Issue' or dataf['Customer Complaint'][i]=='Billing Issue' or dataf['Customer Complaint'][i]=='Data Cap Issue' or dataf['Customer Complaint'][i]=='Payment Issue' or dataf['Customer Complaint'][i]=='Network Issue' or dataf['Customer Complaint'][i]=='Comcast Support Issue' or dataf['Customer Complaint'][i]=='Internet Issue'):
        pass
    else:
        (dataf['Customer Complaint'][i])= 'Comcast Support Issue'
    
dataf
# Out:
# <ipython-input-21-dd91f352ba1f>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   (dataf['Customer Complaint'][i])= 'Comcast Support Issue'
#      Ticket #     Customer Complaint      Date Date_month_year         Time  \
# 0      250635         Internet Issue  22-04-15       22-Apr-15   3:53:50 PM
# 1      223441          Service Issue  04-08-15       04-Aug-15  10:22:56 AM
# 2      242732          Service Issue  18-04-15       18-Apr-15   9:55:47 AM
# 3      277946         Data Cap Issue  05-07-15       05-Jul-15  11:59:35 AM
# 4      307175          Service Issue  26-05-15       26-May-15   1:25:26 PM
# ...       ...                    ...       ...             ...          ...
# 2219   213550          Service Issue  04-02-15       04-Feb-15   9:13:18 AM
# ...

# %%
print(dataf['Customer Complaint'].unique())
# Out:
# ['Internet Issue' 'Service Issue' 'Data Cap Issue' 'Comcast Support Issue'
#  'Network Issue' 'Billing Issue' 'Payment Issue']

# %%
(dataf['Customer Complaint'].value_counts())
# Out:
# Comcast Support Issue    884
# Service Issue            489
# Internet Issue           359
# Billing Issue            232
# Data Cap Issue           182
# Network Issue             69
# Payment Issue              9
# Name: Customer Complaint, dtype: int64

# %% [markdown]
# ## comcast support issue is the Customer Complaint which is the maximum among all other complaint types.

# %%
date = []
for i in df['Date']:
    date.append(i[3:5])

# %%
df['d']= date

# %%
f= df.groupby("Date").count()

# %%
f
# Out:
#           Ticket #  Customer Complaint  Date_month_year  Time  Received Via  \
# Date
# 04-01-15        18                  18               18    18            18
# 04-02-15        27                  27               27    27            27
# 04-03-15        15                  15               15    15            15
# 04-04-15        12                  12               12    12            12
# 04-05-15         6                   6                6     6             6
# ...            ...                 ...              ...   ...           ...
# 29-06-15        51                  51               51    51            51
# 30-04-15        24                  24               24    24            24
# 30-05-15         9                   9                9     9             9
# 30-06-15        53                  53               53    53            53
# 31-05-15        10                  10               10    10            10
#
# ...

# %%
# sns.countplot(x='Ticket #',data=f)

# %%
fig_dims= (80,40)
fig, ax= plt.subplots(figsize=fig_dims)
sns.lineplot(x= df["Date"].sort_values().unique(), y= f['d'], sort= True)
ax.set(xlabel= 'DATE', ylabel= 'COUNT')
# Out:
# [Text(0.5, 0, 'DATE'), Text(0, 0.5, 'COUNT')]

# %% [markdown]
# ## Trend chart for the number of Complaints on daily granualty level

# %%
g=df.groupby("d").count()

# %%
g
# Out:
#     Ticket #  Customer Complaint  Date  Date_month_year  Time  Received Via  \
# d
# 01        55                  55    55               55    55            55
# 02        59                  59    59               59    59            59
# 03        45                  45    45               45    45            45
# 04       375                 375   375              375   375           375
# 05       317                 317   317              317   317           317
# 06      1046                1046  1046             1046  1046          1046
# 07        49                  49    49               49    49            49
# 08        67                  67    67               67    67            67
# 09        55                  55    55               55    55            55
# 10        53                  53    53               53    53            53
# 11        38                  38    38               38    38            38
# ...

# %%
trend2= sns.lineplot(x= df['d'].sort_values().unique(), y= g['Ticket #'], legend= "auto")
trend2.set(xlabel= 'MONTH', ylabel= 'COUNT')
# Out:
# [Text(0.5, 0, 'MONTH'), Text(0, 0.5, 'COUNT')]

# %% [markdown]
# ## Trend chart for the number of Complaints on Monthly granualty level

# %%
def classified(list1):
    if (list1 == 'Open' or list1 == 'Pending'):
        return 'Open'
    elif (list1 =='Closed' or list1 =='Solved' ):
        return 'Closed'

# %%
list2 = df['Status']
print (list2)
# Out:
# 0       Closed
# 1       Closed
# 2       Closed
# 3         Open
# 4       Solved
#          ...
# 2219    Closed
# 2220    Solved
# 2221    Solved
# 2222    Solved
# 2223      Open
# Name: Status, Length: 2224, dtype: object

# %%
df['Status_new'] = list(map(classified,list2))

# %%
df
# Out:
#      Ticket #                                 Customer Complaint      Date  \
# 0      250635                      Comcast Cable Internet Speeds  22-04-15
# 1      223441       Payment disappear - service got disconnected  04-08-15
# 2      242732                                  Speed and Service  18-04-15
# 3      277946  Comcast Imposed a New Usage Cap of 300GB that ...  05-07-15
# 4      307175         Comcast not working and no service to boot  26-05-15
# ...       ...                                                ...       ...
# 2219   213550                               Service Availability  04-02-15
# 2220   318775         Comcast Monthly Billing for Returned Modem  06-02-15
# 2221   331188                            complaint about comcast  06-09-15
# 2222   360489             Extremely unsatisfied Comcast customer  23-06-15
# 2223   363614               Comcast, Ypsilanti MI Internet Speed  24-06-15
#
# ...

# %% [markdown]
# ## Status_new is the new categorical variable with value as Open and Closed. Open & Pending is categorized as Open and  Closed & Solved is categorized as Closed.

# %%
list3= df['State'].value_counts()

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
df['new']= le.fit_transform(df['Status_new'])

# %%
df['new'].value_counts()
# Out:
# 0    1707
# 1     517
# Name: new, dtype: int64

# %%
fig_dims= (60,20)
fig, ax= plt.subplots(figsize=fig_dims)
sns.histplot(data=df, x='State', hue='Status_new', legend= True)
ax.set(xlabel= 'STATE', ylabel= 'COUNT')
# Out:
# [Text(0.5, 0, 'STATE'), Text(0, 0.5, 'COUNT')]

# %% [markdown]
# ## State wise status of complaints in a stacked bar chart.

# %%
print((df['State'].value_counts().index[0]), 'is the state with maximum number of complaints.' )
# Out:
# Georgia is the state with maximum number of complaints.

# %% [markdown]
# ## Georgia is the state with maximum number of complaints

# %%
df2= df.copy()

# %%
j=0
for i in df['Status_new']:
    if(i=='Closed'):
        df2.drop(j, inplace= True)
        
    j= j+1

# %%
list4 = df2['State'].value_counts()

# %%
perc=dict(list4/list3)
perc
# Out:
# {'Alabama': 0.34615384615384615,
#  'Arizona': 0.3,
#  'Arkansas': nan,
#  'California': 0.2772727272727273,
#  'Colorado': 0.275,
#  'Connecticut': 0.25,
#  'Delaware': 0.3333333333333333,
#  'District Of Columbia': 0.125,
#  'District of Columbia': nan,
#  'Florida': 0.1625,
#  'Georgia': 0.2777777777777778,
#  'Illinois': 0.17682926829268292,
#  'Indiana': 0.15254237288135594,
#  'Iowa': nan,
#  'Kansas': 0.5,
#  'Kentucky': 0.42857142857142855,
#  'Louisiana': 0.07692307692307693,
#  'Maine': 0.4,
#  'Maryland': 0.19230769230769232,
#  'Massachusetts': 0.18032786885245902,
#  'Michigan': 0.2,
#  'Minnesota': 0.12121212121212122,
#  'Mississippi': 0.41025641025641024,
#  'Missouri': 0.25,
#  'Montana': nan,
#  'Nevada': nan,
#  'New Hampshire': 0.3333333333333333,
#  'New Jersey': 0.25333333333333335,
#  'New Mexico': 0.26666666666666666,
#  'New York': nan,
#  'North Carolina': nan,
#  'Ohio': nan,
#  'Oregon': 0.2653061224489796,
#  'Pennsylvania': 0.15384615384615385,
# ...

# %%
print(list(perc.keys())[list(perc.values()).index(max(perc.values()))], 'is the state with highest percentage of unresolved complaints.')
# Out:
# Kansas is the state with highest percentage of unresolved complaints.

# %% [markdown]
# ## Kansas is the state with highest percentage of unresolved complaints.

# %%
(((df.groupby('Received Via').count())-(df2.groupby('Received Via').count()))['Ticket #'])*100/df.count()['Ticket #']
# Out:
# Received Via
# Customer Care Call    38.848921
# Internet              37.904676
# Name: Ticket #, dtype: float64

# %% [markdown]
# ### It shows the percentage of cases resolved till date, which were received through the Internet or Customer care calls.
# ## i.e., 38.84% through Customer care calls & 37.90% through the internet.
